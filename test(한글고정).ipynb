# %%
import matplotlib as mpl
print(mpl.matplotlib_fname())

# 한글default 설정 파일 위치
# c:\ProgramData\anaconda3\envs\pandas_numpy\Lib\site-packages\matplotlib\mpl-data\matplotlibrc

# 단 vscode를 관리자계정으로 열어야 함 
# <주의> 커서AI는 관리자계정으로 열먼 큰일 날 수 있음!!!!!!
# 파일 내부에서 -> # font.family:  sans-serif
# font.family:  Malgun Gothic
# axes.unicode_minus: False 
# 수정한것들 주석처리는 X
# 커널 재시작(원래파일 "서울시 범죄현황 분석."파일)
# Out:
# c:\ProgramData\anaconda3\envs\pandas_numpy\Lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
print(mpl.get_cachedir())

#기존에 있던 cache삭제하고 다시

# 다른방법2
#C:\Users\TJ\.matplotlib 가서 json파일 삭제

# 위에 rc파일 복사해서  C:\Users\TJ\.matplotlib 에 붙여넣기
# Out:
# C:\Users\TJ\.matplotlib
