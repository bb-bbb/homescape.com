# %%
# beautifulsoup 4(bs4)
# 1.requests 사용해서 데이터 수집 : 텍스트

# 2.파싱 => DOM Tree 생성 (selector): beautifullSoup
# 2.1 파싱후 -> 4개 오브젝트(어트리뷰트,매쏘드) 생성 -> 4개의  다다른 method 
# 2.2 -> 4개 오브젝트 생성 할 수 있다.(Tag, BeautifulSoup, NavigableString, Comment)
# Tag object: html 문서의 태그에 해당한다. 즉, 태그를 관리한다.(젤 많이 사용함) <a>,<div>,<table>
# BeaitufulSoup object : 문서전체, 최상위(<html>), 태그처럼 작동해서 사용함

# 3.selector(선택)=> 데이터 추출
# Tag,BeautifulSoup object공통 메소드

# tag selector(태그선택자) : tag, id, class, attr
# -find(tag): 단일 선택 => Tag object 반환
# -find_all(tag) : 다중(여러개)선택  => [Tag, Tag,,,,,] & 리스트니까 반복가능

# CSS selector : tag 선택 포함, '상세한' 선택
# -select(selector): [tag object,,,,,,,,]
# -select_one(selector): 첫번째 Tag object 

# 추가 메소드
# -find_parent() : 부모탐색
# -find_next_sibling() : 이후 형제 탐색
# -find_previous_sibling(): 이전 형제 탐색

# Tag object 속성, 메소드
# 속성정리
# .name : 테그 이름 반환
# .attrs : 속성(attribute) 들을 딕셔너리 형태로 반환({'href':'https://www.naver.com','target':'_blink'})
# <a href = 'https://wwww.naver.com' target= '_blink'>

# 방법1.[]'속성이름'] : tag['href'] => 'https://wwww.naver.com' : 특정한 어트리뷰트에 값 넣음
# -1_단점: 키(속성명)없으면 Error발생, 실행이 멈춘다,데이터 수집다시해야함
# 방법2-
# -메소드.get('속성명') : 없으면 None 반환, 멈추지는 않는다.
# -메소드.has_attr('속성명') : 속성이 존재하는 여부(T/F)


# 텍스트(content) 관련 속성 메서드
# 속성
# 오브젝트.string : 해당 태그 내의 텍스트 반환
# 오브젝트.strings : 해당 태그, 하위 태그 내의 텍스트 반환(줄바꿈 공백 포함)
# 메쏘드 
# .get_text() : 해당 태그, 하위 태그 내의 텍스트 반환(줄바꿈 공백 포함), 하나의 문자열로 반환


# 4.데이터프레임 생성
