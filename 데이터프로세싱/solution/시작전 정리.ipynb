# %% [markdown]
# <customer Data>
# joindate: 가입일
# 고객수:2000명
#
# <Orders Data>
# order_date: 주문일
# *주문일과 결제일(payment_date)이 다르다
#
# <payment>
# payment_date: 결제일
#
# <Product Data>
# *category이상해도 넘어가셈
# 상품개수:500개
# stock:재고수
#
# <shipping>
# *delivered: 배송완료
# *shippied:배송중
# endate공백: 배송완료X
#
# <order>
# 행갯수 제일 많음

# %% [markdown]
# ==========문제분석=========
# df:전체데이터
# ->df 좀 까봐야함
